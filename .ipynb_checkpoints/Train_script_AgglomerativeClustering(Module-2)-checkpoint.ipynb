# %%
# import statements
from sklearn.datasets import make_blobs
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
import pandas as pd
from scipy import stats
import seaborn as sns
from mpl_toolkits import mplot3d
import importlib
importlib.import_module('mpl_toolkits.mplot3d').__path__
import matplotlib.pyplot as plt

# %%
df_train=pd.read_csv('partCleaned.csv')

# %%
df_tr=df_train

# %%
clmns = ['AvMoisture%', 'AvN%(dry)','AvP%(dry)', 'AvK%(dry)']

# %%
df_tr_std = stats.zscore(df_tr[clmns])
listOutput=[]

# %%
for i in range(100,200):
    kmeans = KMeans(n_clusters=i, random_state=0).fit(df_tr_std)
    labels = kmeans.labels_
    df_tr['clusters'] = labels
    clmns.extend(['clusters'])
    df_clust=df_tr[clmns]
    df_test=df_tr[['AvMoisture%', 'AvN%(dry)', 'AvP%(dry)', 'AvK%(dry)']]
    listOutput.append(kmeans.score(df_test.values))

# %%
listOutput
# Out:
# [-2421423.2930708304,
#  -2384671.4452173719,
#  -2365250.9955595294,
#  -2349032.0086111468,
#  -2350733.6175377439,
#  -2343655.8399377172,
#  -2333133.1173784314,
#  -2332146.0514166066,
#  -2334030.2598165153,
#  -2333176.2392285699,
#  -2334111.7066937201,
#  -2331330.732991172,
#  -2333081.7726426865,
#  -2331500.0031904392,
#  -2331249.259774412,
#  -2333564.9522352875,
#  -2332622.9588097441,
#  -2331024.4654501597,
#  -2330970.6904853676,
#  -2331915.7195942127,
#  -2331338.4184183371,
#  -2331338.4184183371,
#  -2329699.2137215165,
#  -2329198.1072335653,
#  -2330454.5833566696,
#  -2331471.2154350225,
#  -2330958.8473956799,
#  -2330075.1470925007,
#  -2330642.0939095495,
#  -2330158.4515693169,
#  -2330219.046562118,
#  -2330648.7329480099,
#  -2329939.0197950862,
#  -2329777.5850674263,
#  -2330088.6692180554,
#  -2330015.4971586345,
#  -2330174.3718906022,
#  -2330004.3859829702,
#  -2330052.8760181507,
#  -2329904.5153447455,
#  -2326891.2405317919,
#  -2326746.2820150028,
#  -2329266.0226534428,
#  -2330019.1155067561,
#  -2329909.4467818942,
#  -2329251.5333140665,
#  -2326882.5253193993,
#  -2329083.146317651,
#  -2326088.4779225271,
#  -2328786.6735682953,
#  -2328746.9194327248,
#  -2327161.23790354,
#  -2325952.716677689,
#  -2326093.3563015261,
#  -2326521.8382915212,
#  -2328739.2876845542,
#  -2325792.1033494184,
#  -2325158.0028958623,
#  -2326205.5287364284,
#  -2326504.9673076686,
#  -2325787.0027507758,
#  -2325726.5142716831,
#  -2326745.1851447546,
#  -2325064.266714613,
#  -2326369.8810558282,
#  -2325920.8584615178,
#  -2325763.962064446,
#  -2325835.306853883,
#  -2328741.289694895,
#  -2326664.5757769765,
#  -2325914.5158358696,
#  -2327235.1274957075,
#  -2325609.8048846987,
#  -2326050.2774757557,
#  -2325876.0851596901,
#  -2325899.5103792464,
#  -2325563.428989606,
#  -2325605.5459764274,
#  -2326606.0918539711,
#  -2325815.7697904352,
#  -2326001.9290937912,
#  -2325540.6419347608,
#  -2324832.8621345703,
#  -2325966.7203956852,
#  -2324979.8325530766,
#  -2326097.733727003,
#  -2326028.535383312,
#  -2325632.5263037691,
#  -2325782.9854232618,
#  -2326102.5178361181,
#  -2325479.4197890731,
#  -2326068.3728977414,
#  -2325215.5535173519,
#  -2325109.0775781772,
# ax = fig.add_subplot(111,projection='3d')
# ax.scatter(df_tr['AvN%(dry)'],df_tr['AvP%(dry)'],df_tr['AvK%(dry)'],c='y',marker='o');
# ax.set_xlabel('AvN%(dry)')
# ax.set_ylabel('AvP%(dry)')
# ax.set_zlabel('AvK%(dry)')
# plt.show()

# %%
# from scipy import sparse
# values=np.array([['12.615607','1.028399','0.070979','0.553241']])#,['0.4','0.5','0.6','0.6']])
# print(values)
# #m[inds,np.arange(mshape[1])]=values
# Out:
# [['12.615607' '1.028399' '0.070979' '0.553241']]

# %%
# prediction=kmeans.predict(values)
# print(prediction)
# Out:
# [2]

# %%
df_tr['Crop'].loc[df_tr['clusters'] == prediction[0]]
# Out:
# 15          Alfalfa, for green chop (early bloom, cut 3)
# 18           Alfalfa, for green chop (full bloom, cut 2)
# 19           Alfalfa, for green chop (full bloom, cut 3)
# 21            Alfalfa, for green chop (mid bloom, cut 1)
# 22            Alfalfa, for green chop (mid bloom, cut 2)
# 26            Alfalfa, for green chop (pre bloom, cut 3)
# 54                                                 Apple
# 55                                               Apricot
# 57                        Artichoke-Jerusalum, for tuber
# 60                               Avocado (all varieties)
# 61                                     Avocado (Florida)
# 62                                 Avocadoe (California)
# 63                            Bahiagrass, for green chop
# 66                                                Banana
# 90                          Bermudagrass, for green chop
# 91     Bermudagrass, for green chop (early to mid bloom)
# 92     Bermudagrass, for green chop (full bloom to ma...
# 98                                            Blackberry
# 100                                            Blueberry
# 103               Bluegrass, for green chop (full bloom)
# 104                Bluegrass, for green chop (mid bloom)
# 109      Bluegrass-Kentucky, for green chop (full bloom)
# 110          Bluegrass-Kentucky, for green chop (mature)
# 117                             Bluestem, for green chop
# 118               Bluestem, for green chop (early bloom)
# 120                    Bluestem, for green chop (mature)
# 126                                           Breadfruit
# 130              Bromegrass, for green chop (late bloom)
# 131                  Bromegrass, for green chop (mature)
# 135                                 Bromegrass, for seed
#                              ...
# 612                               Sweet Potato, for vine
# 614             Sweetclover, for green chop (full bloom)
# 615              Sweetclover, for green chop (mid bloom)
# 628                          Switchgrass, for green chop
# 629                Switchgrass, for green chop ( mature)
# 630             Switchgrass, for green chop (full bloom)
# 632             Switchgrass, for green chop (vegetative)
# 634                                            Tangerine
# 635                                       Taro, for corm
# 646         Timothy, for green chop (early to mid bloom)
# 647                 Timothy, for green chop (late bloom)
# 648                     Timothy, for green chop (mature)
# 656                                  Timothy, for silage
# 657                           Timothy, for silage (boot)
# 658                    Timothy, for silage (early bloom)
# 659                     Timothy, for silage (full bloom)
# 660                     Timothy, for silage (milk stage)
# 661                      Timothy, for silage (pre bloom)
# 662                     Timothy, for silage (vegetative)
# 669      Trefoil-Birdsfoot, for green chop (early bloom)
# 690                                Wheat, for green chop
# 691                   Wheat, for green chop (milk stage)
# 701                           Wheatgrass, for green chop
# 703        Wheatgrass, for green chop part (early bloom)
# 709                   Wheatgrass-Crested, for green chop
# 710     Wheatgrass-Crested, for green chop (early bloom)
# 711      Wheatgrass-Crested, for green chop (full bloom)
# 712          Wheatgrass-Crested, for green chop (mature)
# 735                                                  Yam
# 736                                      Barbados Cherry
# Name: Crop, Length: 232, dtype: object

# %%
#df_tr.describe
df_test=df_tr[['AvMoisture%', 'AvN%(dry)', 'AvP%(dry)', 'AvK%(dry)']]
kmeans.score(df_test.values)
# Out:
# -2365250.9955595294
