# %%
import pandas as pd

# %%
data=pd.read_csv("DataSets/crops.csv",na_values=['#VALUE!', '#DIV/0!'])

# %%
data.head()
# Out:
#                                       Crop  \
# 0                                    Acorn
# 1          Alfalfa + Orchardgrass, for hay
# 2  Alfalfa + Orchardgrass, for hay (cut 1)
# 3   Alfalfa + Smooth Brome, for green chop
# 4          Alfalfa + Smooth Brome, for hay
#
#                         ScientificName       Symbol NuContAvailable  \
# 0                          Quercus sp.        QUERC           N,P,K
# 1  Medicago sativa, Dactylis glomerata   MESA, DAGL             N,P
# 2  Medicago sativa, Dactylis glomerata   MESA, DAGL           N,P,K
# 3      Medicago sativa, Bromus inermis  MESA, BRIN2           N,P,K
# 4      Medicago sativa, Bromus inermis  MESA, BRIN2           N,P,K
#
#     PlantPartHarvested    CropCategory    YieldUnit  AvYieldUnitWeight(lb)  \
# 0                Fruit  Tree and fruit  lb of fruit                    1.0
# 1  Aboveground biomass          Forage          ton                 2000.0
# ...

# %%
data.tail()
# Out:
#                         Crop        ScientificName Symbol NuContAvailable  \
# 732  Wheat-Winter, for straw          Triticum sp.  TRITI           N,P,K
# 733      Wildrice, for grain     Zizania palustris  ZIPA3           N,P,K
# 734      Wildrice, for straw     Zizania palustris  ZIPA3           N,P,K
# 735                      Yam         Dioscorea sp.  DIOSC           N,P,K
# 736          Barbados Cherry  Malpighia emarginata   MAEM           N,P,K
#
#     PlantPartHarvested    CropCategory          YieldUnit  \
# 732              Straw  Cereal and oil  lb straw/bu grain
# 733          Caryopsis  Cereal and oil    lb of caryopsis
# 734              Straw  Cereal and oil  lb straw/lb grain
# 735              Tuber       Vegetable        lb of tuber
# 736              Fruit  Tree and fruit        lb of fruit
#
#      AvYieldUnitWeight(lb)  AvMoisture%  AvN%(dry)        ...          \
# 732                 92.475         9.22   0.638957        ...
# ...

# %%
#data['NuContAvailable'].isnull().sum()
reqData=data[['Crop','YieldUnit','AvYieldUnitWeight(lb)','AvMoisture%','AvN%(dry)','AvP%(dry)','AvK%(dry)']]
reqData.fillna(0)
# Out:
#                                                  Crop          YieldUnit  \
# 0                                               Acorn        lb of fruit
# 1                     Alfalfa + Orchardgrass, for hay                ton
# 2             Alfalfa + Orchardgrass, for hay (cut 1)                ton
# 3              Alfalfa + Smooth Brome, for green chop                ton
# 4                     Alfalfa + Smooth Brome, for hay                ton
# 5             Alfalfa + Smooth Brome, for hay (cut 1)                ton
# 6             Alfalfa + Smooth Brome, for hay (cut 2)                ton
# 7     Alfalfa + Timothy, for green chop (50% alfalfa)                ton
# 8                          Alfalfa + Timothy, for hay                ton
# 9                  Alfalfa + Timothy, for hay (cut 1)                ton
# 10                 Alfalfa + Timothy, for hay (cut 2)                ton
# 11                            Alfalfa, for green chop                ton
# ...

# %%
reqData.isna()
# Out:
# Crop                       0
# YieldUnit                  0
# AvYieldUnitWeight(lb)      0
# AvMoisture%                0
# AvN%(dry)                  9
# AvP%(dry)                126
# AvK%(dry)                205
# dtype: int64

# %%
reqData.describe()
# Out:
#        AvYieldUnitWeight(lb)  AvMoisture%   AvN%(dry)   AvP%(dry)   AvK%(dry)
# count             737.000000   737.000000  728.000000  611.000000  532.000000
# mean             1242.542921    45.596947    2.085780    0.278942    1.902496
# std               963.069061    34.628968    1.088682    0.150726    1.007164
# min                 0.588000     2.650000    0.035200    0.016000    0.167000
# 25%                 1.000000    10.580000    1.234700    0.180555    1.200000
# 50%              2000.000000    54.900000    1.979970    0.260000    1.765634
# 75%              2000.000000    78.900000    2.736000    0.360000    2.392500
# max              2000.000000    96.000000    6.567758    1.244510    6.750000

# %%
reqData.to_csv('partCleaned.csv',encoding='utf-8')

# %%
exit()
